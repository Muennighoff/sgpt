# %% [markdown]
# #### **BioASQ BM25**
#
# This notebook preprocesses BioASQ (part of BEIR) & runs BM25 on it.

# %% [markdown]
# ##### Setup BioASQ dataset

# %%
# !kaggle datasets download -d bioasq
# !unzip ./bioasq.zip
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/.kaggle/kaggle.json'
# Downloading bioasq.zip to /home/repos/semanticsearch
# 100%|█████████████████████████████████████▉| 7.93G/7.93G [25:04<00:00, 5.78MB/s]
# 100%|██████████████████████████████████████| 7.93G/7.93G [25:04<00:00, 5.66MB/s]
# Archive:  ./bioasq.zip
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/README
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_1b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_1b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_1b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_2b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_2b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_2b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_2b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_2b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_3b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_3b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_3b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_3b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_3b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_4b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_4b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_4b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_4b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_4b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_5b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_5b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_5b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_5b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_5b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseA_dry-run.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_1b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_1b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_1b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_2b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_2b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_2b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_2b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_2b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_3b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_3b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_3b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_3b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_3b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_4b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_4b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_4b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_4b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_4b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_5b_01.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_5b_02.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_5b_03.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_5b_04.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_5b_05.json
#   inflating: BioASQ-TaskB-testData/BioASQ-TaskB-testData/phaseB_dry-run_.json
#   inflating: allMeSH_2020/allMeSH_2020.json
#   inflating: manual-fixes.csv

# %%
# !kaggle datasets download -d bioasqtraintest
# !unzip ./bioasqtraintest.zip
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/.kaggle/kaggle.json'
# Downloading bioasqtraintest.zip to /home/repos/semanticsearch
#  90%|██████████████████████████████████▏   | 4.00M/4.45M [00:00<00:00, 5.79MB/s]
# 100%|██████████████████████████████████████| 4.45M/4.45M [00:00<00:00, 5.83MB/s]
# Archive:  ./bioasqtraintest.zip
#   inflating: BioASQ-training8b/README
#   inflating: BioASQ-training8b/training8b.json
#   inflating: Task8BGoldenEnriched/Task8BGoldenEnriched/8B1_golden.json
#   inflating: Task8BGoldenEnriched/Task8BGoldenEnriched/8B2_golden.json
#   inflating: Task8BGoldenEnriched/Task8BGoldenEnriched/8B3_golden.json
#   inflating: Task8BGoldenEnriched/Task8BGoldenEnriched/8B4_golden.json
#   inflating: Task8BGoldenEnriched/Task8BGoldenEnriched/8B5_golden.json

# %%
### BioASQ preprocessing ###
import csv
import jsonlines
import json

start_txt = '"abstractText":"'
start_pmid = '","pmid":"'
start_title = '","title":"'


with jsonlines.open('corpus.jsonl', 'w') as jsonl_out:

    with open("allMeSH_2020/allMeSH_2020.json", "r", encoding="utf8", errors="ignore") as f:
         # As the JSON file is too large for memory (19GB), iterate line by line
        for i, line in enumerate(f):

            # first line does not contain data
            if i == 0:
                continue
            
            # Find the indices we need
            txt_idx = line.find(start_txt)
            pmid_idx = line.find(start_pmid)
            title_idx = line.find(start_title)

            assert (txt_idx != -1) and (pmid_idx != -1), f"Could not find Txt: {txt_idx} Pmid: {pmid_idx}"

            abstractText = line[txt_idx + len(start_txt) : pmid_idx]
            pmid = line[pmid_idx + len(start_pmid) : title_idx]

            title = line[title_idx + len(start_title):]
            title_end = title.find('."}')
            title = title[:title_end]
            
            # TODO: Add Title
            line = {"_id": pmid, "text": abstractText, "title": title}
            jsonl_out.write(line)
            
    # Add manual fixes provided by BEIR authors
    with open("manual-fixes.csv", "r") as f:
        csv_f = csv.reader(f)
        for row in csv_f:
            # ID TITLE TEXT
            line = {"_id": row[0], "text": row[2], "title": row[1]}
            jsonl_out.write(line)

# %%
### If you want to benchmark on the BioASQ train dataset [This is not the one used in BEIR] 
def use_train():
    with open("BioASQ-training8b/training8b.json", "r") as content:
        with jsonlines.open(f'queries.jsonl', 'w') as queries_out:
            with open("test.tsv", "w") as record_file:
                record_file.write("query-id\tcorpus-id\tscore\n")
                base_corpus = json.load(content)

                for query in base_corpus["questions"]:
                    query_line = {"_id": query["id"], "text": query["body"]}
                    queries_out.write(query_line)

                    for doc in query["documents"]:
                        doc_id = doc.split("/")[-1]
                        relevance = 1

                        record_file.write(f"{query['id']}\t{doc_id}\t{relevance}\n")
                        
                        
### Test dataset with 500 queries as used in BEIR
test_data_path = "Task8BGoldenEnriched/Task8BGoldenEnriched"
with jsonlines.open(f'queries.jsonl', 'w') as queries_out:
    with open("test.tsv", "w") as record_file:
        # Write header
        record_file.write("query-id\tcorpus-id\tscore\n")
        for test_json in os.listdir(test_data_path):
            with open(os.path.join(test_data_path, test_json), "r") as content:

                queries_answers = json.load(content)

                for query in queries_answers["questions"]:
                    query_line = {"_id": query["id"], "text": query["body"]}
                    queries_out.write(query_line)

                    for doc in query["documents"]:
                        doc_id = doc.split("/")[-1]
                        relevance = 1

                        record_file.write(f"{query['id']}\t{doc_id}\t{relevance}\n")

# %%
# !mkdir bioasq
# !mkdir bioasq/qrels

# !mv ./queries.jsonl bioasq/
# !mv ./corpus.jsonl bioasq/
# !mv ./test.tsv bioasq/qrels/test.tsv

# %% [markdown]
# ##### Run with BM25

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.0.0
# Out:
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/release': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.xml.dom.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.net.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jstatd.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jdwp.agent.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.security.jgss.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jcmd.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.le.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.smartcardio.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.security.sasl.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.scripting.nashorn.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jdeps.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.crypto.ec.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.crypto.cryptoki.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jsobject.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.httpserver.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.vm.compiler.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.xml.crypto.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.naming.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.management.rmi.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.jvmstat.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jfr.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.net.http.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.sctp.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.accessibility.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.compiler.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.management.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.desktop.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.datatransfer.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.logging.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jshell.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.dynalink.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.unsupported.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.instrument.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jdi.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.naming.rmi.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.base.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jlink.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.xml.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.prefs.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.aot.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.scripting.nashorn.shell.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.management.agent.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.charsets.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.ed.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.security.auth.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jartool.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.management.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.localedata.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.attach.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.jconsole.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.opt.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.security.jgss.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.pack.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.sql.rowset.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.sql.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.zipfs.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.vm.ci.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.scripting.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.rmic.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.javadoc.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.internal.vm.compiler.management.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.transaction.xa.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.hotspot.agent.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.editpad.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.se.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.naming.dns.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.compiler.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/java.rmi.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.unsupported.desktop.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods/jdk.management.jfr.jmod': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/jmods': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/logging.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/management/jmxremote.access': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/management/management.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/management/jmxremote.password.template': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/management': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/java.security': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/limited/default_US_export.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/limited/exempt_local.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/limited/default_local.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/limited': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/unlimited/default_US_export.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/unlimited/default_local.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/unlimited': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy/README.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security/java.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/security': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/sound.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/net.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/sdp/sdp.conf.template': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf/sdp': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/conf': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/linux/jawt_md.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/linux/jni_md.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/linux': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/jawt.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/jdwpTransport.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/classfile_constants.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/jvmticmlr.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/jvmti.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include/jni.h': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/include': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jrt-fs.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjsound.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/psfontj2d.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjli.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libawt.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libj2gss.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libfontmanager.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libj2pcsc.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libverify.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjimage.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/modules': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/liblcms.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libj2pkcs11.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjsig.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libzip.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libsctp.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/ct.sym': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libnio.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libawt_headless.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/classlist': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libattach.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libinstrument.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/security/default.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/security/blacklisted.certs': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/security/cacerts': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/security/public_suffix_list.dat': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/security': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libsplashscreen.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libextnet.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjaas.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libmlib_image.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libdt_socket.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jspawnhelper': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/psfont.properties.ja': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjdwp.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jexec': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jvm.cfg': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libmanagement.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libnet.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libprefs.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libsunec.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/librmi.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/tzdb.dat': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjawt.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/server/classes.jsa': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/server/libjsig.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/server/libjvm.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/server/Xusage.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/server': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libsaproc.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjava.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libjavajpeg.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libmanagement_ext.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libawt_xawt.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jfr/profile.jfc': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jfr/default.jfc': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/jfr': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/src.zip': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libunpack.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib/libmanagement_agent.so': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/lib': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.rmic/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.rmic/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.rmic/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.rmic': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/mesa3d.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/lcms.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/opengl.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/xwd.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/giflib.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/harfbuzz.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/colorimaging.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/jpeg.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop/libpng.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.desktop': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdeps/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdeps/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdeps/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdeps': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.naming.dns/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.naming.dns/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.naming.dns/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.naming.dns': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.pack/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.pack/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.pack/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.pack': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jshell/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jshell/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jshell/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jshell': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.net.http/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.net.http/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.net.http/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.net.http': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.sasl/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.sasl/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.sasl/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.sasl': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn.shell/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn.shell/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn.shell/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn.shell': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/xalan.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/xerces.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/bcel.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/jcup.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml/dom.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdwp.agent/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdwp.agent/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdwp.agent/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdwp.agent': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.jvmstat/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.jvmstat/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.jvmstat/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.jvmstat': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.ec/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.ec/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.ec/ecc.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.ec/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.ec': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jcmd/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jcmd/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jcmd/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jcmd': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.rmi/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.rmi/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.rmi/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.rmi': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.charsets/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.charsets/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.charsets/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.charsets': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml.crypto/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml.crypto/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml.crypto/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml.crypto/santuario.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.xml.crypto': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jlink/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jlink/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jlink/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jlink': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.instrument/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.instrument/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.instrument/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.instrument': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.prefs/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.prefs/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.prefs/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.prefs': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.scripting/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.scripting/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.scripting/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.scripting': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.ed/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.ed/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.ed/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.ed': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.net/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.net/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.net/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.net': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jsobject/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jsobject/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jsobject/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jsobject': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.sctp/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.sctp/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.sctp/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.sctp': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.opt/jopt-simple.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.opt/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.opt/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.opt/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.opt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported.desktop/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported.desktop/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported.desktop/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.unsupported.desktop': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.editpad/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.editpad/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.editpad/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.editpad': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.xml.dom/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.xml.dom/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.xml.dom/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.xml.dom': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.ci/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.ci/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.ci/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.ci': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jconsole/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jconsole/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jconsole/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jconsole': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.aot/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.aot/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.aot/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.aot': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler.management/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler.management/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler.management/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler.management': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.vm.compiler': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.jfr/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.jfr/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.jfr/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.jfr': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.accessibility/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.accessibility/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.accessibility/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.accessibility': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jfr/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jfr/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jfr/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jfr': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.localedata/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.localedata/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.localedata/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.localedata/cldr.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.localedata/thaidict.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.localedata': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.zipfs/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.zipfs/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.zipfs/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.zipfs': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.hotspot.agent/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.hotspot.agent/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.hotspot.agent/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.hotspot.agent': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.security.auth/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.security.auth/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.security.auth/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.security.auth': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.attach/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.attach/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.attach/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.attach': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql.rowset/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql.rowset/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql.rowset/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.sql.rowset': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdi/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdi/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdi/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.jdi': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.transaction.xa/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.transaction.xa/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.transaction.xa/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.transaction.xa': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.agent/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.agent/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.agent/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.management.agent': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.cryptoki/pkcs11cryptotoken.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.cryptoki/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.cryptoki/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.cryptoki/pkcs11wrapper.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.cryptoki/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.crypto.cryptoki': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.naming/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.naming/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.naming/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.naming': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.compiler/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.compiler/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.compiler/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.compiler': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.le/jline.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.le/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.le/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.le/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.internal.le': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn/double-conversion.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn/joni.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.scripting.nashorn': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/asm.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/c-libutl.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/icu.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/unicode.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/cldr.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/aes.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base/public_suffix.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.base': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.jgss/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.jgss/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.jgss/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.security.jgss': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/jquery.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/jquery-migrate.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/jqueryUI.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/pako.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc/jszip.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/jdk.javadoc': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.datatransfer/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.datatransfer/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.datatransfer/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.datatransfer': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.management.rmi/ASSEMBLY_EXCEPTION': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.management.rmi/ADDITIONAL_LICENSE_INFO': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.management.rmi/LICENSE': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.management.rmi': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.smartcardio/pcsclite.md': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/jdk/legal/java.smartcardio/ASSEMBLY_EXCEPTION': Operation not permitted
# ...
# chown: changing ownership of 'elasticsearch-7.0.0/modules/reindex/httpasyncclient-4.1.4.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/reindex/commons-logging-1.1.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/reindex/httpcore-nio-4.4.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/reindex': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-ilm/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-ilm/x-pack-ilm-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-ilm/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-ilm/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-ilm': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/mapper-extras/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/mapper-extras/mapper-extras-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/mapper-extras': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-storage-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-xmlsec-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/metrics-core-3.2.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-security-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-saml-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-profile-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/slf4j-api-1.6.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-soap-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-xmlsec-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-saml-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/cryptacular-1.2.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-messaging-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/x-pack-security-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/java-support-7.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/log4j-slf4j-impl-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-messaging-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/guava-19.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-security-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/httpclient-cache-4.5.7.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-storage-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-core-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-soap-impl-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/opensaml-profile-api-3.3.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/xmlsec-2.0.8.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/x-pack-security': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/plugin-descriptor.properties': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/GeoLite2-Country.mmdb': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/GeoLite2-ASN.mmdb': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/GeoLite2-City.mmdb': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/jackson-annotations-2.8.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/maxmind-db-1.2.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/jackson-databind-2.8.11.3.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/geoip2-2.9.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/plugin-security.policy': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip/ingest-geoip-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules/ingest-geoip': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/modules': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/plugins': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/NOTICE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jopt-simple-5.0.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jackson-dataformat-yaml-2.8.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-grouping-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-join-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-spatial-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-queryparser-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-spatial-extras-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/java-version-checker-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-queries-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/spatial4j-0.7.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-misc-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jts-core-1.15.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-backward-codecs-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/log4j-1.2-api-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/log4j-api-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-analyzers-common-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jackson-dataformat-cbor-2.8.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jna-4.5.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-sandbox-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-x-content-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-memory-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/t-digest-3.2.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/hppc-0.7.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-secure-sm-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/snakeyaml-1.17.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/security-cli/bcpkix-jdk15on-1.61.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/security-cli/elasticsearch-security-cli-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/security-cli/bcprov-jdk15on-1.61.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/security-cli': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/plugin-cli/elasticsearch-plugin-cli-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/plugin-cli/bcprov-jdk15on-1.61.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/plugin-cli/bcpg-jdk15on-1.61.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools/plugin-cli': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/tools': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-highlighter-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/HdrHistogram-2.1.9.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-geo-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-spatial3d-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/joda-time-2.10.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-core-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-cli-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-core-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/lucene-suggest-8.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jackson-dataformat-smile-2.8.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/elasticsearch-launchers-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/log4j-core-2.11.1.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/jackson-core-2.8.11.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib/plugin-classloader-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/lib': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-croneval': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/x-pack-env': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-migrate': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-cli': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-keystore': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-certutil': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-sql-cli-7.0.0.jar': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-env': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-node': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-users': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-syskeygen': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/x-pack-watcher-env': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-plugin': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-setup-passwords': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/x-pack-security-env': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-saml-metadata': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-certgen': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-shard': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin/elasticsearch-sql-cli': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/bin': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/logs': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/README.textile': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0/LICENSE.txt': Operation not permitted
# chown: changing ownership of 'elasticsearch-7.0.0': Operation not permitted
# ---------------------------------------------------------------------------
# SubprocessError                           Traceback (most recent call last)
# <ipython-input-2-cd85b980ee8c> in <module>
#       5 import os
#       6 from subprocess import Popen, PIPE, STDOUT
# ----> 7 es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'],
#       8                   stdout=PIPE, stderr=STDOUT,
#       9                   preexec_fn=lambda: os.setuid(1)  # as daemon
#
# ~/miniconda3/envs/semanticsearch/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     856                             encoding=encoding, errors=errors)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#     860                                 startupinfo, creationflags, shell,
#
# ~/miniconda3/envs/semanticsearch/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1703                         err_msg = os.strerror(errno_num)
#    1704                     raise child_exception_type(errno_num, err_msg, err_filename)
# -> 1705                 raise child_exception_type(err_msg)
#    1706
#    1707
#
# SubprocessError: Exception occurred in preexec_fn.

# %%
# start server
import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )

# %%
# wait a bit then test - should show something like cluster_name" : "elasticsearch" ...
#!curl -X GET "localhost:9200/"
# Alternative way to check if BM25 is working; without using curl
# !wget "localhost:9200/"
# !cat index.html
# !rm index.html
# Out:
# --2021-12-09 14:58:43--  http://localhost:9200/
# Resolving localhost (localhost)... 127.0.0.1
# Connecting to localhost (localhost)|127.0.0.1|:9200... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 501 [application/json]
# Saving to: ‘index.html’
#
# index.html          100%[===================>]     501  --.-KB/s    in 0s
#
# 2021-12-09 14:58:43 (63,8 MB/s) - ‘index.html’ saved [501/501]
#
# {
#   "name" : "james-new",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "jTPlAc85QhqmVhSBGc7AOQ",
#   "version" : {
#     "number" : "7.0.0",
#     "build_flavor" : "default",
#     "build_type" : "tar",
#     "build_hash" : "b7e28a7",
#     "build_date" : "2019-04-05T22:55:32.697037Z",
#     "build_snapshot" : false,
#     "lucene_version" : "8.0.0",
#     "minimum_wire_compatibility_version" : "6.7.0",
#     "minimum_index_compatibility_version" : "6.0.0-beta1"
#   },
#   "tagline" : "You Know, for Search"
# }

# %%
### TRAIN DATASET RESULTS ###

import json

from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.search.lexical import BM25Search as BM25
from beir.retrieval.evaluation import EvaluateRetrieval


def run_bm25(dataset, data_path, initialize = True, hostname = "localhost"):
    corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")
    model = BM25(index_name=dataset, hostname=hostname, initialize=initialize)
    retriever = EvaluateRetrieval(model)
    #### Retrieve dense results (format of results is identical to qrels)
    results = retriever.retrieve(corpus, queries)
    # Save scores for top 1000 docs for each query, i.e. 1000 * queries lines
    with open(f"./results_{dataset}.json", 'w') as fp:
        json.dump(results, fp)
    ndcg, _map, recall, precision = retriever.evaluate(qrels, results, retriever.k_values)
    return ndcg


### Signal 1M

#run_bm25("signal1m", "signal1m")

##### TREC-News

#run_bm25("trec-news", "trec-news")

##### TREC-Robust

#run_bm25("robust04", "robust04")

##### BioASQ

run_bm25("bioasq", "bioasq")
# Out:
# /home/miniconda3/envs/semanticsearch/lib/python3.8/site-packages/beir/datasets/data_loader.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/14913938 [00:00<?, ?it/s]
#   0%|          | 0/14913854 [00:00<?, ?docs/s]
# que: 100%|██████████| 26/26 [01:13<00:00,  2.81s/it]
# {'NDCG@1': 0.37095,
#  'NDCG@3': 0.35248,
#  'NDCG@5': 0.34372,
#  'NDCG@10': 0.33488,
#  'NDCG@100': 0.39548,
#  'NDCG@1000': 0.43395}

# %%
### TEST DATASET RESULTS ###

import json

from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.search.lexical import BM25Search as BM25
from beir.retrieval.evaluation import EvaluateRetrieval


def run_bm25(dataset, data_path, initialize = True, hostname = "localhost"):
    corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")
    model = BM25(index_name=dataset, hostname=hostname, initialize=initialize)
    retriever = EvaluateRetrieval(model)
    #### Retrieve dense results (format of results is identical to qrels)
    results = retriever.retrieve(corpus, queries)
    # Save scores for top 1000 docs for each query, i.e. 1000 * queries lines
    with open(f"./results_{dataset}.json", 'w') as fp:
        json.dump(results, fp)
    ndcg, _map, recall, precision = retriever.evaluate(qrels, results, retriever.k_values)
    return ndcg


### Signal 1M

#run_bm25("signal1m", "signal1m")

##### TREC-News

#run_bm25("trec-news", "trec-news")

##### TREC-Robust

#run_bm25("robust04", "robust04")

##### BioASQ

run_bm25("bioasq", "bioasq")
# Out:
# /home/miniconda3/envs/semanticsearch/lib/python3.8/site-packages/beir/datasets/data_loader.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/14914714 [00:00<?, ?it/s]
#   0%|          | 0/14914604 [00:00<?, ?docs/s]
# que: 100%|██████████| 4/4 [00:45<00:00, 11.39s/it]
# {'NDCG@1': 0.472,
#  'NDCG@3': 0.48468,
#  'NDCG@5': 0.48426,
#  'NDCG@10': 0.48838,
#  'NDCG@100': 0.55887,
#  'NDCG@1000': 0.58621}
